# %% [markdown]
# # Criação de Meta-Base

# %% [markdown]
# ## Considerações sobre Aprendizado Ativo

# %% [markdown]
# Para que os experimentos sejam executados, é necessária a criação de uma meta-base a respeito do processo de **aprendizado ativo** (AL).  Contudo, algumas variáveis podem influenciar diretamente o processo de aprendizado ativo, sendo elas:
#
# - Quantidade Inicial de Dados Rotulados (  $\vert X^0_{labeled}\vert$ )
# - Quantidade de consultas a serem realizados ($q$)
# - Estratégia de consulta utilizada (*query strategy*)
# - Quantidade de instâncias retornadas por uma consulta (*batch size*)
# - Método utilizado para ordenar as instâncias retornadas por uma consulta
# - Tamanho do conjunto de teste para avaliar o aprendizado

# %% [markdown]
# ### Quantidade Inicial de Dados Rotulados

# %% [markdown]
# Em tese, a ideia principal do AL é tentar popuar esforços de anotação ao rotular as instâncias que melhor descrevem um conjunto de dados. Dessa forma, na maioria dos casos lidamos com situações em que há uma pequena quantidade de instâncias rotuladas, apenas o suficiente para iniciar o processo de aprenzidado ativo

# %% [markdown]
# > Qual a quantidade ideal de dados anotados inicialmente?

# %% [markdown]
# Como o nosso objetivo é simular várias configurações diferentes de active learning para cada uma das bases, é necessário pensar em alguma manera de deixar esse processo o mais reprodutível possível, algumas ideias são:
#
# 1.  $\vert X_{labeled} \vert = n$, onde $n$ representa uma constante arbitrária
# 2.  $\vert X_{labeled} \vert = c$, onde $c$ representa o número de classes no problema de classificação
# 2.  $\vert X_{labeled} \vert = \alpha\times\vert X\vert$, onde $\alpha \in (0, 1]$ representa uma constante de proporcionalidade

# %% [markdown]
# ### Quantidade de consultas a serem realizadas

# %% [markdown]
# Como a quantidade de instâncias varia conforme o conjunto de dados, também devemos decidir como escolheremos esse parâmetro. Dessa forma podemos utilizar soluções similares às citadas acima, porém baseado no tamanho do conjunto de dados

# %% [markdown]
# ### Estratégia de Consulta

# %% [markdown]
# Estratégias baseadas na incerteza de um classificador:
# - [ ] Classification Uncertainty
# - [ ] Classification Margin
# - [ ] Classification Entropy

# %% [markdown]
# Estratégias baseadas em discordância entre modelos
#
# - [ ] Vote Entropy
# - [ ] Consensus Entropy
# - [ ] Max Disagreement

# %% [markdown]
# ### Quantidade de instâncias retornadas por consulta

# %% [markdown]
# Originalmente, as estratégias de consulta está preocupadas em selecionar a instância mais interessante para ser rotulado, contudo o que ocorre geralmente é que o anotador não está disposto a anotar apenas uma instância e esperar uma próxima iteração do processo de AL ser executado novamente. Muito tempo e recursos podem ser otimizados se mais de uma instância for retornada por consulta.
#
# Todavia, simplesmente retornar as $n$ consultas com a maior pontuação, pode não ser uma boa ideia (embora as vezes seja uma alternativa). Sendo assim Cardoso et. al formularam uma maneira de ranquear essas instâncias

# %% [markdown]
# $score = \alpha(1 - \Phi(x, X_{labeled})) + (1 - \alpha) U(x),$

# %% [markdown]
# Onde $\alpha = \frac{|X_{unlabeled}|}{|X_{unlabeled}| + |X_{labeled}|}$, $U(x)$ é a incerteza das predições para $x$ e $\Phi$ é uma função de similaridade. Dessa forma é possível medir o quão bem o espaço de características foi explorado perto de $x$

# %% [markdown]
# ## Criação de Meta-base

# %% [markdown]
# ### Simulação de Cenário

# %%
from metabase_builder import MetaBaseBuilder

# %% [markdown]
# #### Classificadores

# %%
from sklearn.svm import LinearSVC, SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

class SVCLinear(SVC):
    pass
    
clf_list = [
    SVCLinear(kernel='linear', probability=True),
    KNeighborsClassifier(),
    GaussianNB(),
]

# %% [markdown]
# #### Estratégias de consulta

# %%
from modAL.uncertainty import uncertainty_sampling, margin_sampling, entropy_sampling
from modAL.batch import uncertainty_batch_sampling
from modAL.disagreement import consensus_entropy_sampling, vote_entropy_sampling, max_disagreement_sampling

query_strategies = [ 
    uncertainty_sampling,
    uncertainty_batch_sampling, 
    margin_sampling,
]

# %% [markdown]
# ### Conjunto de dados de exemplo

# %%
import warnings

import openml

from config import dataset_ids

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    dataset = openml.datasets.get_dataset(dataset_ids[0])
    
dataset
# Out:
# OpenML Dataset
# ==============
# Name..........: kr-vs-kp
# Version.......: 1
# Format........: ARFF
# Upload Date...: 2014-04-06 23:19:28
# Licence.......: Public
# Download URL..: https://api.openml.org/data/v1/download/3/kr-vs-kp.arff
# OpenML URL....: https://www.openml.org/d/3
# # of features.: 37
# # of instances: 3196

# %% [markdown]
# #### Geração de metabase para dataset

# %%
builder = MetaBaseBuilder(estimators=clf_list,
                          query_strategies=query_strategies,
                          n_queries=5,
                          initial_l_size=5)

# %%
builder.build(dataset)
# Out:
# 2024-03-07 23:01:16,618 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::0 - Criando instância...
# 2024-03-07 23:01:16,618 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::0 - Criando instância...
# 2024-03-07 23:03:26,939 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::0 - Instância criada.
# 2024-03-07 23:03:26,939 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::0 - Instância criada.
# 2024-03-07 23:03:26,962 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::1 - Criando instância...
# 2024-03-07 23:03:26,962 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::1 - Criando instância...
# 2024-03-07 23:05:21,150 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::1 - Instância criada.
# 2024-03-07 23:05:21,150 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::1 - Instância criada.
# 2024-03-07 23:05:21,165 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::2 - Criando instância...
# 2024-03-07 23:05:21,165 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::2 - Criando instância...
# 2024-03-07 23:07:08,068 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::2 - Instância criada.
# 2024-03-07 23:07:08,068 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::2 - Instância criada.
# 2024-03-07 23:07:08,096 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::3 - Criando instância...
# 2024-03-07 23:07:08,096 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::3 - Criando instância...
# 2024-03-07 23:08:59,870 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::3 - Instância criada.
# 2024-03-07 23:08:59,870 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::3 - Instância criada.
# 2024-03-07 23:08:59,880 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::4 - Criando instância...
# 2024-03-07 23:08:59,880 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::4 - Criando instância...
# 2024-03-07 23:10:51,469 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::4 - Instância criada.
# 2024-03-07 23:10:51,469 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_sampling::4 - Instância criada.
# 2024-03-07 23:10:56,300 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_batch_sampling::0 - Criando instância...
# 2024-03-07 23:10:56,300 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_batch_sampling::0 - Criando instância...
# 2024-03-07 23:12:44,959 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_batch_sampling::0 - Instância criada.
# 2024-03-07 23:12:44,959 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_batch_sampling::0 - Instância criada.
# 2024-03-07 23:12:51,547 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_batch_sampling::1 - Criando instância...
# 2024-03-07 23:12:51,547 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_batch_sampling::1 - Criando instância...
# 2024-03-07 23:14:55,278 - INFO - 3_kr-vs-kp - SVCLinear::uncertainty_batch_sampling
- INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_sampling::4 - Criando instância...
# 2024-03-07 23:37:24,584 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_sampling::4 - Criando instância...
# 2024-03-07 23:39:10,161 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_sampling::4 - Instância criada.
# 2024-03-07 23:39:10,161 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_sampling::4 - Instância criada.
# 2024-03-07 23:39:16,644 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::0 - Criando instância...
# 2024-03-07 23:39:16,644 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::0 - Criando instância...
# 2024-03-07 23:41:07,638 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::0 - Instância criada.
# 2024-03-07 23:41:07,638 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::0 - Instância criada.
# 2024-03-07 23:41:12,920 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::1 - Criando instância...
# 2024-03-07 23:41:12,920 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::1 - Criando instância...
# 2024-03-07 23:43:02,931 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::1 - Instância criada.
# 2024-03-07 23:43:02,931 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::1 - Instância criada.
# 2024-03-07 23:43:08,744 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::2 - Criando instância...
# 2024-03-07 23:43:08,744 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::2 - Criando instância...
# 2024-03-07 23:45:03,132 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::2 - Instância criada.
# 2024-03-07 23:45:03,132 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::2 - Instância criada.
# 2024-03-07 23:45:09,068 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::3 - Criando instância...
# 2024-03-07 23:45:09,068 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::3 - Criando instância...
# 2024-03-07 23:47:13,382 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::3 - Instância criada.
# 2024-03-07 23:47:13,382 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::3 - Instância criada.
# 2024-03-07 23:47:19,899 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::4 - Criando instância...
# 2024-03-07 23:47:19,899 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::4 - Criando instância...
# 2024-03-07 23:49:27,804 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::4 - Instância criada.
# 2024-03-07 23:49:27,804 - INFO - 3_kr-vs-kp - KNeighborsClassifier::uncertainty_batch_sampling::4 - Instância criada.
# 2024-03-07 23:49:28,702 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::0 - Criando instância...
# 2024-03-07 23:49:28,702 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::0 - Criando instância...
# 2024-03-07 23:51:16,490 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::0 - Instância criada.
# 2024-03-07 23:51:16,490 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::0 - Instância criada.
# 2024-03-07 23:51:17,260 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::1 - Criando instância...
# 2024-03-07 23:51:17,260 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::1 - Criando instância...
# 2024-03-07 23:53:07,918 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::1 - Instância criada.
# 2024-03-07 23:53:07,918 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::1 - Instância criada.
# 2024-03-07 23:53:08,894 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::2 - Criando instância...
# 2024-03-07 23:53:08,894 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::2 - Criando instância...
# 2024-03-07 23:54:26,889 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::2 - Instância criada.
# 2024-03-07 23:54:26,889 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::2 - Instância criada.
# 2024-03-07 23:54:27,644 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::3 - Criando instância...
# 2024-03-07 23:54:27,644 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::3 - Criando instância...
# 2024-03-07 23:55:51,362 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::3 - Instância criada.
# 2024-03-07 23:55:51,362 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::3 - Instância criada.
# 2024-03-07 23:55:52,153 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::4 - Criando instância...
# 2024-03-07 23:55:52,153 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::4 - Criando instância...
# 2024-03-07 23:57:36,501 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::4 - Instância criada.
# 2024-03-07 23:57:36,501 - INFO - 3_kr-vs-kp - KNeighborsClassifier::margin_sampling::4 - Instância criada.
# 2024-03-07 23:57:36,509 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::0 - Criando instância...
# 2024-03-07 23:57:36,509 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::0 - Criando instância...
# 2024-03-07 23:59:19,164 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::0 - Instância criada.
# 2024-03-07 23:59:19,164 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::0 - Instância criada.
# 2024-03-07 23:59:19,174 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::1 - Criando instância...
# 2024-03-07 23:59:19,174 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::1 - Criando instância...
# 2024-03-08 00:01:03,736 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::1 - Instância criada.
# 2024-03-08 00:01:03,736 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::1 - Instância criada.
# 2024-03-08 00:01:03,755 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::2 - Criando instância...
# 2024-03-08 00:01:03,755 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::2 - Criando instância...
# 2024-03-08 00:02:42,275 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::2 - Instância criada.
# 2024-03-08 00:02:42,275 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::2 - Instância criada.
# 2024-03-08 00:02:42,301 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::3 - Criando instância...
# 2024-03-08 00:02:42,301 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::3 - Criando instância...
# 2024-03-08 00:04:12,809 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::3 - Instância criada.
# 2024-03-08 00:04:12,809 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::3 - Instância criada.
# 2024-03-08 00:04:12,824 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::4 - Criando instância...
# 2024-03-08 00:04:12,824 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::4 - Criando instância...
# 2024-03-08 00:05:58,897 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::4 - Instância criada.
# 2024-03-08 00:05:58,897 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_sampling::4 - Instância criada.
# 2024-03-08 00:06:03,444 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::0 - Criando instância...
# 2024-03-08 00:06:03,444 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::0 - Criando instância...
# 2024-03-08 00:07:51,331 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::0 - Instância criada.
# 2024-03-08 00:07:51,331 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::0 - Instância criada.
# 2024-03-08 00:07:55,472 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::1 - Criando instância...
# 2024-03-08 00:07:55,472 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::1 - Criando instância...
# 2024-03-08 00:09:31,837 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::1 - Instância criada.
# 2024-03-08 00:09:31,837 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::1 - Instância criada.
# 2024-03-08 00:09:37,437 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::2 - Criando instância...
# 2024-03-08 00:09:37,437 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::2 - Criando instância...
# 2024-03-08 00:11:10,386 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::2 - Instância criada.
# 2024-03-08 00:11:10,386 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::2 - Instância criada.
# 2024-03-08 00:11:15,604 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::3 - Criando instância...
# 2024-03-08 00:11:15,604 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::3 - Criando instância...
# 2024-03-08 00:12:46,064 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::3 - Instância criada.
# 2024-03-08 00:12:46,064 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::3 - Instância criada.
# 2024-03-08 00:12:50,792 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::4 - Criando instância...
# 2024-03-08 00:12:50,792 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::4 - Criando instância...
# 2024-03-08 00:14:37,353 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::4 - Instância criada.
# 2024-03-08 00:14:37,353 - INFO - 3_kr-vs-kp - GaussianNB::uncertainty_batch_sampling::4 - Instância criada.
# 2024-03-08 00:14:37,364 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::0 - Criando instância...
# 2024-03-08 00:14:37,364 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::0 - Criando instância...
# 2024-03-08 00:16:38,082 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::0 - Instância criada.
# 2024-03-08 00:16:38,082 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::0 - Instância criada.
# 2024-03-08 00:16:38,092 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::1 - Criando instância...
# 2024-03-08 00:16:38,092 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::1 - Criando instância...
# 2024-03-08 00:18:01,235 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::1 - Instância criada.
# 2024-03-08 00:18:01,235 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::1 - Instância criada.
# 2024-03-08 00:18:01,250 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::2 - Criando instância...
# 2024-03-08 00:18:01,250 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::2 - Criando instância...
# 2024-03-08 00:19:20,788 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::2 - Instância criada.
# 2024-03-08 00:19:20,788 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::2 - Instância criada.
# 2024-03-08 00:19:20,796 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::3 - Criando instância...
# 2024-03-08 00:19:20,796 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::3 - Criando instância...
# 2024-03-08 00:20:53,916 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::3 - Instância criada.
# 2024-03-08 00:20:53,916 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::3 - Instância criada.
# 2024-03-08 00:20:53,970 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::4 - Criando instância...
# 2024-03-08 00:20:53,970 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::4 - Criando instância...
# 2024-03-08 00:22:18,980 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::4 - Instância criada.
# 2024-03-08 00:22:18,980 - INFO - 3_kr-vs-kp - GaussianNB::margin_sampling::4 - Instância criada.
#                estimator              query-strategy  accuracy  f1-micro  \
# 0              SVCLinear        uncertainty_sampling  0.759700  0.759700
# 1              SVCLinear        uncertainty_sampling  0.788486  0.788486
# 2              SVCLinear        uncertainty_sampling  0.762203  0.762203
# 3              SVCLinear        uncertainty_sampling  0.774718  0.774718
# 4              SVCLinear        uncertainty_sampling  0.806008  0.806008
# 5              SVCLinear  uncertainty_batch_sampling  0.690864  0.690864
# 6              SVCLinear  uncertainty_batch_sampling  0.745932  0.745932
# 7              SVCLinear  uncertainty_batch_sampling  0.717146  0.717146
# 8              SVCLinear  uncertainty_batch_sampling  0.783479  0.783479
# 9              SVCLinear  uncertainty_batch_sampling  0.789737  0.789737
# 10             SVCLinear             margin_sampling  0.659574  0.659574
# 11             SVCLinear             margin_sampling  0.678348  0.678348
# 12             SVCLinear             margin_sampling  0.652065  0.652065
# 13             SVCLinear             margin_sampling  0.705882  0.705882
# 14             SVCLinear             margin_sampling  0.804756  0.804756
# 15  KNeighborsClassifier        uncertainty_sampling  0.556946  0.556946
# 16  KNeighborsClassifier        uncertainty_sampling  0.579474  0.579474
# 17  KNeighborsClassifier        uncertainty_sampling  0.607009  0.607009
# 18  KNeighborsClassifier        uncertainty_sampling  0.634543  0.634543
# 19  KNeighborsClassifier        uncertainty_sampling  0.668335  0.668335
# 20  KNeighborsClassifier  uncertainty_batch_sampling  0.541927  0.541927
# 21  KNeighborsClassifier  uncertainty_batch_sampling  0.602003  0.602003
# 22  KNeighborsClassifier  uncertainty_batch_sampling  0.604506  0.604506
# 23  KNeighborsClassifier  uncertainty_batch_sampling  0.591990  0.591990
# 24  KNeighborsClassifier  uncertainty_batch_sampling  0.605757  0.605757
# 25  KNeighborsClassifier             margin_sampling  0.642053  0.642053
# 26  KNeighborsClassifier             margin_sampling  0.673342  0.673342
# 27  KNeighborsClassifier             margin_sampling  0.677096  0.677096
# 28  KNeighborsClassifier             margin_sampling  0.683354  0.683354
# 29  KNeighborsClassifier             margin_sampling  0.688360  0.688360
# 30            GaussianNB        uncertainty_sampling  0.559449  0.559449
# 31            GaussianNB        uncertainty_sampling  0.538173  0.538173
# 32            GaussianNB        uncertainty_sampling  0.584481  0.584481
# 33            GaussianNB        uncertainty_sampling  0.685857  0.685857
# 34            GaussianNB        uncertainty_sampling  0.685857  0.685857
# 35            GaussianNB  uncertainty_batch_sampling  0.685857  0.685857
# 36            GaussianNB  uncertainty_batch_sampling  0.630788  0.630788
# 37            GaussianNB  uncertainty_batch_sampling  0.565707  0.565707
# 38            GaussianNB  uncertainty_batch_sampling  0.610763  0.610763
# 39            GaussianNB  uncertainty_batch_sampling  0.580726  0.580726
# 40            GaussianNB             margin_sampling  0.657071  0.657071
# 41            GaussianNB             margin_sampling  0.648310  0.648310
#
#     wg_dist.mean  wg_dist.sd  worst_node.mean  worst_node.mean.relative  \
# 0       4.024132    0.272462         0.512134                       2.0
# 1       4.023766    0.273027         0.524500                       1.0
# 2       4.024348    0.272331         0.515126                       1.0
# 3       4.023847    0.271654         0.512000                       1.0
# 4       4.024373    0.271611         0.523629                       1.0
# 5       4.024132    0.272462         0.525941                       1.0
# 6       4.021930    0.270995         0.542894                       2.0
# 7       4.019842    0.269552         0.529832                       1.0
# 8       4.017951    0.268642         0.522921                       1.0
# 9       4.016900    0.268607         0.520253                       1.0
# 10      4.024132    0.272462         0.518410                       1.0
# 11      4.024057    0.272649         0.541716                       2.0
# 12      4.024199    0.272578         0.522269                       1.0
# 13      4.024565    0.272560         0.511563                       1.0
# 14      4.023992    0.272726         0.529114                       2.0
# 15      4.024132    0.272462         0.518828                       1.0
# 16      4.024014    0.272731         0.524521                       2.0
# 17      4.022958    0.271696         0.528992                       1.0
# 18      4.023488    0.271480         0.536441                       2.0
# 19      4.023356    0.271412         0.525738                       1.0
# 20      4.024132    0.272462         0.524268                       1.0
# 21      4.021653    0.270493         0.517805                       1.0
# 22      4.019900    0.269620         0.522269                       1.0
# 23      4.018262    0.269224         0.518280                       1.0
# 24      4.016506    0.268637         0.513080                       1.0
# 25      4.024132    0.272462         0.520921                       2.0
# 26      4.024915    0.272090         0.530841                       1.0
# 27      4.024506    0.272084         0.512605                       1.0
# 28      4.025057    0.271902         0.513273                       1.0
# 29      4.024860    0.272003         0.528692                       2.0
# 30      4.024132    0.272462         0.526778                       1.0
# 31      4.024538    0.272552         0.535444                       1.0
# 32      4.024151    0.272754         0.526471                       2.0
# 33      4.024529    0.272775         0.515803                       1.0
# 34      4.024372    0.273088         0.519831                       1.0
# 35      4.024132    0.272462         0.521757                       1.0
# 36      4.021653    0.270493         0.508166                       1.0
# 37      4.019755    0.269334         0.522689                       1.0
# 38      4.017926    0.268684         0.529674                       2.0
# 39      4.016504    0.268553         0.521519                       1.0
# 40      4.024132    0.272462         0.535983                       1.0
# 41      4.023440    0.272409         0.529574                       1.0
# 42      4.024235    0.271988         0.515546                       1.0
# 43      4.025299    0.271370         0.526742                       2.0
# 44      4.025642    0.271532         0.513924                       1.0
#
#     worst_node.sd  worst_node.sd.relative
# 0        0.021714                     5.0
# 1        0.031400                     6.0
# 2        0.035773                     6.0
# 3        0.023919                     6.0
# 4        0.029060                     6.0
# 5        0.031685                     6.0
# 6        0.063175                     6.0
# 7        0.027118                     6.0
# 8        0.030345                     6.0
# 9        0.035473                     6.0
# 10       0.034920                     6.0
# 11       0.040893                     6.0
# 12       0.017941                     6.0
# 13       0.020581                     6.0
# 14       0.037540                     6.0
# 15       0.031558                     5.0
# 16       0.041813                     6.0
# 17       0.037657                     6.0
# 18       0.044001                     6.0
# 19       0.024699                     5.0
# 20       0.031065                     6.0
# 21       0.018325                     5.0
# 22       0.038102                     6.0
# 23       0.036122                     6.0
# 24       0.033057                     6.0
# 25       0.037019                     6.0
# 26       0.028314                     5.0
# 27       0.022928                     5.0
# 28       0.011577                     1.0
# 29       0.032260                     6.0
# 30       0.031893                     6.0
# 31       0.020553                     6.0
# 32       0.040157                     6.0
# 33       0.021203                     6.0
# 34       0.032306                     6.0
# 35       0.032232                     6.0
# 36       0.022856                     6.0
# 37       0.024031                     6.0
# 38       0.032556                     6.0
# 39       0.030113                     6.0
# 40       0.038924                     6.0
# 41       0.015187                     1.0
# 42       0.033733                     6.0
# 43       0.006469                     1.0
# 44       0.020167                     5.0
#
# [45 rows x 185 columns]

# %%
builder.metabase.head(30)
# Out:
#                estimator              query-strategy  accuracy  f1-micro  \
# 0              SVCLinear        uncertainty_sampling  0.759700  0.759700
# 1              SVCLinear        uncertainty_sampling  0.788486  0.788486
# 2              SVCLinear        uncertainty_sampling  0.762203  0.762203
# 3              SVCLinear        uncertainty_sampling  0.774718  0.774718
# 4              SVCLinear        uncertainty_sampling  0.806008  0.806008
# 5              SVCLinear  uncertainty_batch_sampling  0.690864  0.690864
# 6              SVCLinear  uncertainty_batch_sampling  0.745932  0.745932
# 7              SVCLinear  uncertainty_batch_sampling  0.717146  0.717146
# 8              SVCLinear  uncertainty_batch_sampling  0.783479  0.783479
# 9              SVCLinear  uncertainty_batch_sampling  0.789737  0.789737
# 10             SVCLinear             margin_sampling  0.659574  0.659574
# 11             SVCLinear             margin_sampling  0.678348  0.678348
# 12             SVCLinear             margin_sampling  0.652065  0.652065
# 13             SVCLinear             margin_sampling  0.705882  0.705882
# 14             SVCLinear             margin_sampling  0.804756  0.804756
# 15  KNeighborsClassifier        uncertainty_sampling  0.556946  0.556946
# 16  KNeighborsClassifier        uncertainty_sampling  0.579474  0.579474
# 17  KNeighborsClassifier        uncertainty_sampling  0.607009  0.607009
# 18  KNeighborsClassifier        uncertainty_sampling  0.634543  0.634543
# 19  KNeighborsClassifier        uncertainty_sampling  0.668335  0.668335
# 20  KNeighborsClassifier  uncertainty_batch_sampling  0.541927  0.541927
# 21  KNeighborsClassifier  uncertainty_batch_sampling  0.602003  0.602003
# 22  KNeighborsClassifier  uncertainty_batch_sampling  0.604506  0.604506
# 23  KNeighborsClassifier  uncertainty_batch_sampling  0.591990  0.591990
# 24  KNeighborsClassifier  uncertainty_batch_sampling  0.605757  0.605757
# 25  KNeighborsClassifier             margin_sampling  0.642053  0.642053
# 26  KNeighborsClassifier             margin_sampling  0.673342  0.673342
# 27  KNeighborsClassifier             margin_sampling  0.677096  0.677096
# 28  KNeighborsClassifier             margin_sampling  0.683354  0.683354
# 29  KNeighborsClassifier             margin_sampling  0.688360  0.688360
#
#     f1-macro  f1-weighted  attr_conc.mean  attr_conc.sd  attr_ent.mean  \
# 0   0.759534     0.760143        0.123004      0.212792       0.544273
# 1   0.788421     0.788388        0.054304      0.144670       0.544138
# 2   0.762095     0.762089        0.085863      0.184782       0.544261
# 3   0.774676     0.774625        0.024687      0.122260       0.544074
# 4   0.805988     0.805942        0.131834      0.213937       0.544198
# 22     0.372201  ...           0.046744  5.666198  1.508771e-07  0.357024
# 23     0.372093  ...           0.047052  5.661729  1.515204e-07  0.356756
# 24     0.372206  ...           0.047233  5.645475  1.521801e-07  0.355798
# 25     0.371938  ...           0.046868  5.672254  1.496031e-07  0.356193
# 26     0.371967  ...           0.046911  5.679949  1.502381e-07  0.356496
# 27     0.372015  ...           0.046495  5.682555  1.508429e-07  0.356497
# 28     0.372042  ...           0.046457  5.687142  1.514633e-07  0.356726
# 29     0.372008  ...           0.046830  5.685602  1.520988e-07  0.356955
#
#     wg_dist.mean  wg_dist.sd  worst_node.mean  worst_node.mean.relative  \
# 0       4.024132    0.272462         0.512134                       2.0
# 1       4.023766    0.273027         0.524500                       1.0
# 2       4.024348    0.272331         0.515126                       1.0
# 3       4.023847    0.271654         0.512000                       1.0
# 4       4.024373    0.271611         0.523629                       1.0
# 5       4.024132    0.272462         0.525941                       1.0
# 6       4.021930    0.270995         0.542894                       2.0
# 7       4.019842    0.269552         0.529832                       1.0
# 8       4.017951    0.268642         0.522921                       1.0
# 9       4.016900    0.268607         0.520253                       1.0
# 10      4.024132    0.272462         0.518410                       1.0
# 11      4.024057    0.272649         0.541716                       2.0
# 12      4.024199    0.272578         0.522269                       1.0
# 13      4.024565    0.272560         0.511563                       1.0
# 14      4.023992    0.272726         0.529114                       2.0
# 15      4.024132    0.272462         0.518828                       1.0
# 16      4.024014    0.272731         0.524521                       2.0
# 17      4.022958    0.271696         0.528992                       1.0
# 18      4.023488    0.271480         0.536441                       2.0
# 19      4.023356    0.271412         0.525738                       1.0
# 20      4.024132    0.272462         0.524268                       1.0
# 21      4.021653    0.270493         0.517805                       1.0
# 22      4.019900    0.269620         0.522269                       1.0
# 23      4.018262    0.269224         0.518280                       1.0
# 24      4.016506    0.268637         0.513080                       1.0
# 25      4.024132    0.272462         0.520921                       2.0
# 26      4.024915    0.272090         0.530841                       1.0
# 27      4.024506    0.272084         0.512605                       1.0
# 28      4.025057    0.271902         0.513273                       1.0
# 29      4.024860    0.272003         0.528692                       2.0
#
#     worst_node.sd  worst_node.sd.relative
# 0        0.021714                     5.0
# 1        0.031400                     6.0
# 2        0.035773                     6.0
# 3        0.023919                     6.0
# 4        0.029060                     6.0
# 5        0.031685                     6.0
# 6        0.063175                     6.0
# 7        0.027118                     6.0
# 8        0.030345                     6.0
# 9        0.035473                     6.0
# 10       0.034920                     6.0
# 11       0.040893                     6.0
# 12       0.017941                     6.0
# 13       0.020581                     6.0
# 14       0.037540                     6.0
# 15       0.031558                     5.0
# 16       0.041813                     6.0
# 17       0.037657                     6.0
# 18       0.044001                     6.0
# 19       0.024699                     5.0
# 20       0.031065                     6.0
# 21       0.018325                     5.0
# 22       0.038102                     6.0
# 23       0.036122                     6.0
# 24       0.033057                     6.0
# 25       0.037019                     6.0
# 26       0.028314                     5.0
# 27       0.022928                     5.0
# 28       0.011577                     1.0
# 29       0.032260                     6.0
#
# [30 rows x 185 columns]
