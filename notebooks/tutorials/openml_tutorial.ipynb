# %% [markdown]
# # Instalação de Bases de Dados do OpenML

# %%
import openml
import pandas as pd
from openml.datasets import edit_dataset, fork_dataset, get_dataset

# %%
datalist = openml.datasets.list_datasets(output_format="dataframe")

# %%
datalist.head()
# Out:
#    did        name  version uploader  status format  MajorityClassSize  \
# 2    2      anneal        1        1  active   ARFF              684.0
# 3    3    kr-vs-kp        1        1  active   ARFF             1669.0
# 4    4       labor        1        1  active   ARFF               37.0
# 5    5  arrhythmia        1        1  active   ARFF              245.0
# 6    6      letter        1        1  active   ARFF              813.0
#
#    MaxNominalAttDistinctValues  MinorityClassSize  NumberOfClasses  \
# 2                          7.0                8.0              5.0
# 3                          3.0             1527.0              2.0
# 4                          3.0               20.0              2.0
# 5                         13.0                2.0             13.0
# 6                         26.0              734.0             26.0
#
#    NumberOfFeatures  NumberOfInstances  NumberOfInstancesWithMissingValues  \
# ...

# %% [markdown]
# ## Exercise 1
# - Find datasets with more than 1000 examples
# - Find a dataset called 'eeg_eye_state'.
# - Find all datasets with more than 50 classes

# %%
datalist[datalist.NumberOfInstances > 10000].sort_values(["NumberOfInstances"]).head(20)
# Out:
#          did                                name  version uploader  status  \
# 43832  43832  Apple-Complete-Stock-Data1980-2020        1    30125  active
# 23515  23515                              sulfur        1      225  active
# 44003  44003                              sulfur        2    26324  active
# 44020  44020                              sulfur        3    26324  active
# 44145  44145                              sulfur        4    26324  active
# 43968  43968                                 pol        4    26324  active
# 44122  44122                                 pol       10    26324  active
# 43956  43956                                 pol        3    26324  active
# 44113  44113                                 pol        9    26324  active
# 44082  44082                                 pol        8    26324  active
# 4133    4133                  kdd_internet_usage        2        2  active
# ...

# %%
datalist.query('name == "eeg-eye-state"')
# Out:
#        did           name  version uploader  status format  MajorityClassSize  \
# 1471  1471  eeg-eye-state        1       64  active   ARFF             8257.0
#
#       MaxNominalAttDistinctValues  MinorityClassSize  NumberOfClasses  \
# 1471                          2.0             6723.0              2.0
#
#       NumberOfFeatures  NumberOfInstances  NumberOfInstancesWithMissingValues  \
# 1471              15.0            14980.0                                 0.0
#
#       NumberOfMissingValues  NumberOfNumericFeatures  NumberOfSymbolicFeatures
# 1471                    0.0                     14.0                       1.0

# %%
datalist.query("NumberOfClasses > 50")
# Out:
#          did                                               name  version  \
# 1491    1491                          one-hundred-plants-margin        1
# 1492    1492                           one-hundred-plants-shape        1
# 1493    1493                         one-hundred-plants-texture        1
# 4552    4552                                  BachChoralHarmony        1
# 41167  41167                                             dionis        1
# 41169  41169                                             helena        1
# 41960  41960                                      seattlecrime6        1
# 41983  41983                                          CIFAR-100        1
# 42078  42078                                       beer_reviews        4
# 42087  42087                                       beer_reviews        5
# 42088  42088                                       beer_reviews        6
# 42089  42089                                 vancouver_employee        1
# ...

# %% [markdown]
# ## Download datasets

# %%
dataset = openml.datasets.get_dataset(1471)
# Out:
# /tmp/ipykernel_54138/1968058793.py:1: FutureWarning: Starting from Version 0.15 `download_data`, `download_qualities`, and `download_features_meta_data` will all be ``False`` instead of ``True`` by default to enable lazy loading. To disable this message until version 0.15 explicitly set `download_data`, `download_qualities`, and `download_features_meta_data` to a bool while calling `get_dataset`.
#   dataset = openml.datasets.get_dataset(1471)

# %%
print("Name:", dataset.name )
print("Target Feature:", dataset.default_target_attribute )
print("URL:", dataset.url )
# Out:
# Name: eeg-eye-state
# Target Feature: Class
# URL: https://api.openml.org/data/v1/download/1587924/eeg-eye-state.arff

# %%
print(dataset.description)
# Out:
# **Author**: Oliver Roesler
# **Source**: [UCI](https://archive.ics.uci.edu/ml/datasets/EEG+Eye+State), Baden-Wuerttemberg, Cooperative State University (DHBW), Stuttgart, Germany
# **Please cite**: [UCI](https://archive.ics.uci.edu/ml/citation_policy.html)
#
# All data is from one continuous EEG measurement with the Emotiv EEG Neuroheadset. The duration of the measurement was 117 seconds. The eye state was detected via a camera during the EEG measurement and added later manually to the file after analyzing the video frames. '1' indicates the eye-closed and '0' the eye-open state. All values are in chronological order with the first measured value at the top of the data.
#
# The features correspond to 14 EEG measurements from the headset, originally labeled AF3, F7, F3, FC5, T7, P, O1, O2, P8, T8, FC6, F4, F8, AF4, in that order.

# %% [markdown]
# ### Get the actual data

# %% [markdown]
# opeml-python returns data as pandas dataframes, and also some aditional meta-data that we don't  care about right now

# %%
eeg, *_ = dataset.get_data()

# %%
eeg
# Out:
#             V1       V2       V3       V4       V5       V6       V7       V8  \
# 0      4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1      4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2      4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3      4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4      4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14975  4281.03  3990.26  4245.64  4116.92  4333.85  4614.36  4074.87  4625.64
# 14976  4276.92  3991.79  4245.13  4110.77  4332.82  4615.38  4073.33  4621.54
# 14977  4277.44  3990.77  4246.67  4113.85  4333.33  4615.38  4072.82  4623.59
# 14978  4284.62  3991.79  4251.28  4122.05  4334.36  4616.41  4080.51  4628.72
# 14979  4287.69  3997.44  4260.00  4121.03  4333.33  4616.41  4088.72  4638.46
#
# ...

# %%
X, y, categorical_indicator, attribute_names = dataset.get_data(
    target=dataset.default_target_attribute )

# %%
X.head()
# Out:
#         V1       V2       V3       V4       V5       V6       V7       V8  \
# 0  4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1  4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2  4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3  4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4  4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
#
#         V9      V10      V11      V12      V13      V14
# 0  4222.05  4238.46  4211.28  4280.51  4635.90  4393.85
# 1  4210.77  4226.67  4207.69  4279.49  4632.82  4384.10
# 2  4207.69  4222.05  4206.67  4282.05  4628.72  4389.23
# 3  4217.44  4235.38  4210.77  4287.69  4632.31  4396.41
# 4  4210.77  4244.10  4212.82  4288.21  4632.82  4398.46

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14980 entries, 0 to 14979
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      14980 non-null  float64
#  1   V2      14980 non-null  float64
#  2   V3      14980 non-null  float64
#  3   V4      14980 non-null  float64
#  4   V5      14980 non-null  float64
#  5   V6      14980 non-null  float64
#  6   V7      14980 non-null  float64
#  7   V8      14980 non-null  float64
#  8   V9      14980 non-null  float64
#  9   V10     14980 non-null  float64
#  10  V11     14980 non-null  float64
#  11  V12     14980 non-null  float64
#  12  V13     14980 non-null  float64
#  13  V14     14980 non-null  float64
# dtypes: float64(14)
# memory usage: 1.6 MB

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14975    2
# 14976    2
# 14977    2
# 14978    2
# 14979    2
# Name: Class, Length: 14980, dtype: category
# Categories (2, object): ['1' < '2']

# %%
categorical_indicator, attribute_names
# Out:
# ([False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   False],
#  ['V1',
#   'V2',
#   'V3',
#   'V4',
#   'V5',
#   'V6',
#   'V7',
#   'V8',
#   'V9',
#   'V10',
#   'V11',
#   'V12',
#   'V13',
#   'V14'])

# %%
dataset.data_file
# Out:
# '/home/gabriel/.cache/openml/org/openml/www/datasets/1471/dataset.arff'
